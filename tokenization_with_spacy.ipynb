# %% [markdown]
# tokenization with spacy

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
mystring = '"We\'re moving to L.A.!"'
print(mystring)
# Out:
# "We're moving to L.A.!"

# %%
doc= nlp(mystring)
for token in doc:
    print(token.text, end='|')
# Out:
# "|We|'re|moving|to|L.A.|!|"|

# %%
doc2 = nlp('we are here to help! send snail-mail, email spport@orsite.com or visit s at https://www.orsite.com')
for t in doc2:
    print(t)
# Out:
# we
# are
# here
# to
# help
# !
# send
# snail
# -
# mail
# ,
# email
# spport@orsite.com
# or
# visit
# s
# at
# https://www.orsite.com

# %%
doc3= nlp(u'a 7km nyc can ride costs $10.30')
for t in doc3:
    print(t)
# Out:
# a
# 7
# km
# nyc
# can
# ride
# costs
# $
# 10.30

# %% [markdown]
# exceptions

# %%
doc4= nlp(u"Let's visit St. Louis in the U.S. next year.")
for t in doc4:
  print(t)
# Out:
# Let
# 's
# visit
# St.
# Louis
# in
# the
# U.S.
# next
# year
# .

# %% [markdown]
# conting tokens

# %%
len(doc)
# Out:
# 8

# %% [markdown]
# contin vocab entries

# %%
len(doc.vocab)
# Out:
# 791

# %%
doc5= nlp(u'It is better to give than to receive.')
doc5[7]
# Out:
# receive

# %%
doc5[2:7]
# Out:
# better to give than to

# %%
doc5[-4:]
# Out:
# than to receive.

# %% [markdown]
# tokens cannot be reassigned

# %%
doc6= nlp(u'My dinner was horrible.')
doc7= nlp(u'Your dinner was delicious.')

# %%
doc6[3]= doc7[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-730702940.py in <cell line: 0>()
# ----> 1 doc6[3]= doc7[3]
#
# TypeError: 'spacy.tokens.doc.Doc' object does not support item assignment

# %% [markdown]
# named entities

# %%
doc8= nlp(u'Apple to build a Hong Kong factory for $6 million')
for token in doc8:
    print(token.text, end='|')

print('\n----')

for ent in doc8.ents:
    print(ent.text+' - '+ent.label_+' - '+str(spacy.explain(ent.label_)))
# Out:
# Apple|to|build|a|Hong|Kong|factory|for|$|6|million|
# ----
# Apple - ORG - Companies, agencies, institutions, etc.
# Hong Kong - GPE - Countries, cities, states
# $6 million - MONEY - Monetary values, including unit

# %%
len(doc8.ents)
# Out:
# 3

# %% [markdown]
# noun chunks

# %%
doc9 = nlp(u'autonomous cars shift insurance liability toward manufacturers.')
for chunk in doc9.noun_chunks:
    print(chunk.text)
# Out:
# autonomous cars
# insurance liability
# manufacturers

# %%
doc10 = nlp(u'red cars do not carry higher insurance rates')
for chunk in doc10.noun_chunks:
    print(chunk.text)
# Out:
# red cars
# higher insurance rates

# %%
doc11 = nlp(u'he was a one-eyed, one-horned, flying, purple people-eater.')
for chunk in doc11.noun_chunks:
    print(chunk.text)
# Out:
# he
# a one-eyed, one-horned, flying, purple people-eater

# %% [markdown]
# built in visualizer

# %%
from spacy import displacy

doc= nlp(u'Apple is going to build a U.K. factory for $6 million.')
displacy.render(doc, style='dep', jupyter=True, options={'distance':70})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="dcba53fb1c6d46b1b8cc898d5dd43cfb-0" class="displacy" width="890" height="277.0" direction="ltr" style="max-width: none; height: 277.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="120">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="120">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">going</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="260">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="260">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">build</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">U.K.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="540">factory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="540">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">million.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-0" stroke-width="2px" d="M70,142.0 C70,72.0 180.0,72.0 180.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,144.0 L62,132.0 78,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-1" stroke-width="2px" d="M140,142.0 C140,107.0 175.0,107.0 175.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M140,144.0 L132,132.0 148,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-2" stroke-width="2px" d="M280,142.0 C280,107.0 315.0,107.0 315.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M280,144.0 L272,132.0 288,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-3" stroke-width="2px" d="M210,142.0 C210,72.0 320.0,72.0 320.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M320.0,144.0 L328.0,132.0 312.0,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-4" stroke-width="2px" d="M420,142.0 C420,72.0 530.0,72.0 530.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,144.0 L412,132.0 428,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-5" stroke-width="2px" d="M490,142.0 C490,107.0 525.0,107.0 525.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M490,144.0 L482,132.0 498,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-6" stroke-width="2px" d="M350,142.0 C350,37.0 535.0,37.0 535.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M535.0,144.0 L543.0,132.0 527.0,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-7" stroke-width="2px" d="M350,142.0 C350,2.0 610.0,2.0 610.0,142.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dcba53fb1c6d46b1b8cc898d5dd43cfb-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M610.0,144.0 L618.0,132.0 602.0,132.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dcba53fb1c6d46b1b8cc8

# %%
doc = nlp(u'over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million.')
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  iPods for a profit of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div></span>
